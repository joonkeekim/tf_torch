# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %cd fastCampus/
# Out:
# /content/gdrive/My Drive/Colab Notebooks/fastCampus

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/gdrive/My Drive/Colab Notebooks/fastCampus/.git/

# %%
# !git config --global user.email "joonkee0701@gmail.com"
# !git config --global user.name "joonkeekim"

# %%
# !git add .

# %%
# !git commit -m "from colab"
# Out:
# [master (root-commit) c5510b3] from colab
#  26 files changed, 26 insertions(+)
#  create mode 100644 6_23(python_tuto).ipynb
#  create mode 100644 6_27(python_tuto).ipynb
#  create mode 100644 6_28(python_tuto).ipynb
#  create mode 100644 7 12-2.ipynb
#  create mode 100644 7 12.ipynb
#  create mode 100644 7 13.ipynb
#  create mode 100644 7 18.ipynb
#  create mode 100644 7 19-2.ipynb
#  create mode 100644 7 19.ipynb
#  create mode 100644 7 22.ipynb
#  create mode 100644 7 23-2.ipynb
#  create mode 100644 7 23.ipynb
#  create mode 100644 7 24-2.ipynb
#  create mode 100644 7 24.ipynb
#  create mode 100644 7 27.ipynb
#  create mode 100644 7 28(histroy,predict,save).ipynb
#  create mode 100644 7 28(torch_data_loader).ipynb
#  create mode 100644 7 29(kaggle).ipynb
#  create mode 100644 7 29(torch_preprocess).ipynb
#  create mode 100644 7 3.ipynb
#  create mode 100644 7 4.ipynb
#  create mode 100644 7 7_8.ipynb
#  create mode 100644 7 8.ipynb
#  create mode 100644 7 9-2.ipynb
# ...

# %%
# !git remote add origin https://github.com/joonkeekim/fcMachineLearning.git

# %%
# !git push -u origin master
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
